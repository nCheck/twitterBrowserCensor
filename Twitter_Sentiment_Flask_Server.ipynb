# %%
#Flask Server
# !pip install flask-ngrok
# !git clone https://github.com/sonaliiguleria/twitterSentimentBackend.git
# %cd twitterSentimentBackend
# Out:
# ...
# Cloning into 'twitterSentimentBackend'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 81 (delta 6), reused 10 (delta 1), pack-reused 64
# Unpacking objects: 100% (81/81), done.
# /content/twitterSentimentBackend

# %%
# Copy the Running on NGROK URL
# !python app.py
# Out:
# loading model...
# model loaded
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://b6ab932202f2.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# tweet df                                               tweets  id
# 0  BJP@BJP4India·6sBJP National President Shri @J...   0
# 1  Ranveer Allahbadia@BeerBicepsGuy·4hMy 5 most m...   1
# 2  Chrome Developers@ChromiumDev [LIVE] #webdevLI...   2
# 3  Bhuvan Bam@Bhuvan_Bam·1hThe Ultimate Roast. To...   3
# 4  Anupam Kher@AnupamPKher·9hअपने पिछले एक ट्वीट ...   4
# 5  Gaurav Taneja@flyingbeast320·7hDIY Home DroneT...   5
# 6  Virat Kohli@imVkohli·4hHey H @hardikpandya7 lo...   6
# 7  Abhi and Niyu@abhiandniyu·20hOur latest video ...   7
# ...
